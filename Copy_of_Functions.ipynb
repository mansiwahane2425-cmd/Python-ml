# %% [markdown]
# <a href="https://colab.research.google.com/github/mansiwahane2425-cmd/Python-ml/blob/main/Copy_of_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Functions

# %%
def funct1():
  print("hello")
funct1()
# Out:
# hello

# %% [markdown]
# ### 1. Basic Function Definition

# %%
def funct1(fname):
  print(fname)
funct1("fchchg")
# Out:
# fchchg

# %% [markdown]
# ### 2. Function with One Argument

# %%
def funct1(fname, lname ):
  print(fname + "  " +lname)
funct1("fchchg", "vsdvhsg")
# Out:
# fchchg  vsdvhsg

# %% [markdown]
# ### 3. Function with Multiple Arguments

# %%
def funct1(*kid):
  print(kid[2])
funct1("a", "b", "c")
funct1("a", "b", "r", "d")
funct1("a", "b", "t", "d", "e")
# Out:
# c
# r
# t

# %% [markdown]
# ### 4. Arbitrary Arguments (`*args`)

# %%
def funct1( k,j,i):
  print(" the values of i = {}, j={}, k={}" .format(i,j,k))

funct1(i=2, j=6, k=8)
# Out:
#  the values of i = 2, j=6, k=8

# %% [markdown]
# ### 5. Keyword Arguments

# %%
def funct1( ** var):
   print(var["i"])
funct1(i=2, j=6, k=8)
# Out:
# 2

# %% [markdown]
# ### 6. Arbitrary Keyword Arguments (`**kwargs`)

# %%
def funct1(food):
  for i in food:
    print(i)

fruits=["apple", "banana", "cherry"]
funct1(fruits)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ### 7. Passing a List as an Argument

# %%
def funct1 (country='India'):
  print ("my country name is " + country)
funct1("newyork")
funct1()
# Out:
# my country name is newyork
# my country name is India

# %% [markdown]
# ### 8. Default Parameter Value

# %%
def funct1 (x):
  return 5*x

print(funct1(5))
# Out:
# 25

# %% [markdown]
# ### 9. Function Return Value

# %%
def funct1 ():
  pass

# %% [markdown]
# ### 10. The `pass` Statement

# %%
x=10
def funct1():
  x=10
  x= x*10
  print(x)

funct1()
print(x)
# Out:
# 100
# 10

# %% [markdown]
# ### 11. Local vs. Global Variables (without `global`)

# %%
x=10
def funct1():
  x=globals()['x']
  x=10
  x= x*10
  globals()['x']=x
  print(x)

funct1()
print(x)
# Out:
# 100
# 100

# %% [markdown]
# ### 12. Modifying Global Variables using `globals()`

# %%
x=10
def funct1():
  global x
  x= x*100
  print(x)

funct1()
print(x)
# Out:
# 1000
# 1000

# %% [markdown]
# ### 13. Modifying Global Variables using `global` Keyword

# %%
# explicitly float accept  what to do
def greet(name:float):
  print(type(name))
greet(1234)
greet("welcome")
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### 14. Type Hinting (Informational)

# %%
num= input("enter a number")
num
# Out:
# enter a number34
# '34'

# %% [markdown]
# ### 15. User Input (`input()`)

# %%
str= input("enter a string"). split(",")
# Out:
# enter a stringmy, vandana  is a teacher

# %% [markdown]
# ### 16. User Input with String Manipulation

# %%
str
# Out:
# ['my', ' vandana  is a teacher']

# %% [markdown]
# ### 17. Displaying the Result of String Split

# %%
print(1,2,3,4)
# Out:
# 1 2 3 4

# %% [markdown]
# ### 18. Basic `print()` Function

# %%
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4

# %% [markdown]
# ### 19. `print()` with `sep` Argument

# %%
print(1,2,3,4, sep='*' ,end= '&')
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4&1*2*3*4

# %% [markdown]
# ### 20. `print()` with `sep` and `end` Arguments

# %%
x=3;y=4
print( "vcnsv{1}jhsjhd{0}" . format(x,y))
# Out:
# vcnsv4jhsjhd3

# %% [markdown]
# ### 21. String Formatting (`format()` method - Positional Arguments)

# %%
print( "{}jghcjgcj{}" . format('bread', 'butter'))
print( "{1}jghcjgcj{0}" . format('bread', 'butter'))
# Out:
# breadjghcjgcjbutter
# butterjghcjgcjbread
